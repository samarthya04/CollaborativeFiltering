# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.metrics import pairwise_distances
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cols_u = ['user_id', 'age', 'sex', 'occupation', 'zip_code']
users=pd.read_csv('/content/drive/MyDrive/ml-100k/u.user', sep='|', names=cols_u, encoding='latin-1', parse_dates=True)

ratings_u = ['user_id', 'movie_id', 'rating', 'timestamp']
ratings=pd.read_csv('/content/drive/MyDrive/ml-100k/u.data', sep='\t', names=ratings_u, encoding='latin-1')

movies_u = ['movie_id' , 'title', 'release_date', 'video_release_date', 'imdb_url']
movies = pd.read_csv('/content/drive/MyDrive/ml-100k/u.item', sep='|', names=movies_u, usecols=range(5), encoding='latin-1')



movie_ratings=pd.merge(movies,ratings)
movie_df=pd.merge(movie_ratings,users)

movie_df.head(500)
# Out:
#      movie_id                                          title release_date  \
# 0           1                               Toy Story (1995)  01-Jan-1995
# 1           4                              Get Shorty (1995)  01-Jan-1995
# 2           5                                 Copycat (1995)  01-Jan-1995
# 3           7                          Twelve Monkeys (1995)  01-Jan-1995
# 4           8                                    Babe (1995)  01-Jan-1995
# ..        ...                                            ...          ...
# 495       214                   Pink Floyd - The Wall (1982)  01-Jan-1982
# 496       222                Star Trek: First Contact (1996)  22-Nov-1996
# 497       227  Star Trek VI: The Undiscovered Country (1991)  01-Jan-1991
# 498       228            Star Trek: The Wrath of Khan (1982)  01-Jan-1982
# 499       234                                    Jaws (1975)  01-Jan-1975
#
#      video_release_date                                           imdb_url  \
# 0                   NaN  http://us.imdb.com/M/title-exact?Toy%20Story%2...
# 1                   NaN  http://us.imdb.com/M/title-exact?Get%20Shorty%...
# 2                   NaN  http://us.imdb.com/M/title-exact?Copycat%20(1995)
# 3                   NaN  http://us.imdb.com/M/title-exact?Twelve%20Monk...
# 4                   NaN     http://us.imdb.com/M/title-exact?Babe%20(1995)
# ..                  ...                                                ...
# 495                 NaN  http://us.imdb.com/M/title-exact?Pink%20Floyd%...
# 496                 NaN  http://us.imdb.com/M/title-exact?Star%20Trek:%...
# 497                 NaN  http://us.imdb.com/M/title-exact?Star%20Trek%2...
# 498                 NaN  http://us.imdb.com/M/title-exact?Star%20Trek:%...
# 499                 NaN     http://us.imdb.com/M/title-exact?Jaws%20(1975)
#
#      user_id  rating  timestamp  age sex occupation zip_code
# 0        308       4  887736532   60   M    retired    95076
# 1        308       5  887737890   60   M    retired    95076
# 2        308       4  887739608   60   M    retired    95076
# 3        308       4  887738847   60   M    retired    95076
# 4        308       5  887736696   60   M    retired    95076
# ..       ...     ...        ...  ...  ..        ...      ...
# 495      148       5  877019882   33   M   engineer    97006
# 496      148       4  877398901   33   M   engineer    97006
# 497      148       4  877399083   33   M   engineer    97006
# 498      148       4  877016514   33   M   engineer    97006
# 499      148       3  877020297   33   M   engineer    97006
#
# [500 rows x 12 columns]

# %%
#This is for the normalization comment it out for now
min_rating = ratings['rating'].min()
max_rating = ratings['rating'].max()

ratings['rating'] = (ratings['rating'] - min_rating) / (max_rating - min_rating)

ratings.head()
# Out:
#    user_id  movie_id  rating  timestamp
# 0      196       242    0.50  881250949
# 1      186       302    0.50  891717742
# 2       22       377    0.00  878887116
# 3      244        51    0.25  880606923
# 4      166       346    0.00  886397596

# %%
user_input_percent = 0.3
subset_percent = 0.7

num_ratings = len(ratings)
num_user_input = int(num_ratings * user_input_percent)
num_subset = int(num_ratings * subset_percent)

user_input_ratings = ratings.sample(n=num_user_input, random_state=42)
subset_ratings = ratings.drop(user_input_ratings.index)
user_input_ratings
# Out:
#        user_id  movie_id  rating  timestamp
# 75721      877       381    0.75  882677345
# 80184      815       602    0.50  878694269
# 19864       94       431    0.75  891721716
# 76699      416       875    0.25  876696938
# 92991      500       182    0.25  883873556
# ...        ...       ...     ...        ...
# 42648      385       919    0.75  879440158
# 86306      833       429    0.50  875123506
# 45466      246       550    0.50  884922740
# 63724      758        20    0.75  881976574
# 34122       65       735    0.75  879216769
#
# [30000 rows x 4 columns]

# %%
import numpy as np
from google.colab import autoviz

def histogram(df, colname, num_bins=20, figscale=1):
  from matplotlib import pyplot as plt
  df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
  plt.gca().spines[['top', 'right',]].set_visible(False)
  plt.tight_layout()
  return autoviz.MplChart.from_current_mpl_state()

chart = histogram(user_input_ratings, *['movie_id'], **{})
chart
# Out:
# <img style="width: 180px;" src="...">

# %%
import numpy as np
from google.colab import autoviz

def histogram(df, colname, num_bins=20, figscale=1):
  from matplotlib import pyplot as plt
  df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
  plt.gca().spines[['top', 'right',]].set_visible(False)
  plt.tight_layout()
  return autoviz.MplChart.from_current_mpl_state()

chart = histogram(user_input_ratings, *['rating'], **{})
chart
# Out:
# <img style="width: 180px;" src="...">

# %%
movie_df.drop(movie_df.columns[[3,4,7]], axis=1, inplace=True)
ratings.drop("timestamp", inplace=True, axis=1)
movies.drop(movies.columns[[3,4]], inplace=True, axis=1)
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   movie_id      100000 non-null  int64
#  1   title         100000 non-null  object
#  2   release_date  99991 non-null   object
#  3   user_id       100000 non-null  int64
#  4   rating        100000 non-null  int64
#  5   age           100000 non-null  int64
#  6   sex           100000 non-null  object
#  7   occupation    100000 non-null  object
#  8   zip_code      100000 non-null  object
# dtypes: int64(4), object(5)
# memory usage: 7.6+ MB

# %% [markdown]
# Finding the users who have rated the similar movies and grouping the common users simultaneously.

# %%
userSubset = subset_ratings[subset_ratings['movie_id'].isin(user_input_ratings['movie_id'].tolist())]
userSubset.head()
# Out:
#    user_id  movie_id  rating  timestamp
# 0      196       242    0.50  881250949
# 1      186       302    0.50  891717742
# 2       22       377    0.00  878887116
# 3      244        51    0.25  880606923
# 4      166       346    0.00  886397596

# %%
userSubsetGroup = userSubset.groupby(['user_id'])
userSubsetGroup.get_group(500)
# Out:
#        user_id  movie_id  rating  timestamp
# 24169      500       111    0.75  888538350
# 24307      500       781    0.50  883874776
# 24509      500      1012    0.75  883865021
# 24521      500       159    0.25  883876251
# 24557      500       665    0.50  883876714
# ...        ...       ...     ...        ...
# 96710      500      1057    0.50  883877359
# 97046      500       242    0.50  891916883
# 98372      500       383    0.50  883877467
# 98749      500       546    0.75  887720050
# 99947      500      1010    0.75  883865483
#
# [155 rows x 4 columns]

# %% [markdown]
# Sort the subset values with respect to the  number of ratings.

# %%
movieSubsetGroup = userSubset.groupby(['movie_id'])
movieSubsetGroup.get_group(222)
# Out:
#        user_id  movie_id  rating  timestamp
# 296        119       222    1.00  874775311
# 566         21       222    0.25  874951382
# 1017        56       222    1.00  892679439
# 1131       296       222    1.00  884196640
# 1299         1       222    0.75  878873388
# ...        ...       ...     ...        ...
# 95882      665       222    0.50  884290676
# 96726      560       222    0.75  879976706
# 96897      895       222    0.50  879437965
# 98679      429       222    0.75  882385518
# 98885      838       222    0.75  887064356
#
# [250 rows x 4 columns]

# %%
movieSubsetGroup=sorted(movieSubsetGroup,key=lambda x: len(x[1]), reverse=True)
movieSubsetGroup[0:3]
# Out:
# <ipython-input-80-209f4e50f6dd>:1: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   movieSubsetGroup=sorted(movieSubsetGroup,key=lambda x: len(x[1]), reverse=True)
# [(50,
#          user_id  movie_id  rating  timestamp
#   857         79        50    0.75  891271545
#   1052         2        50    1.00  888552084
#   1376       227        50    0.75  879035347
#   1678        99        50    1.00  885679998
#   1789       305        50    1.00  886321799
#   ...        ...       ...     ...        ...
#   98854      648        50    1.00  882211016
#   99567      749        50    1.00  878846978
#   99643      886        50    1.00  876031501
#   99853      739        50    0.75  886958895
#   99928      903        50    1.00  891031329
#
#   [386 rows x 4 columns]),
#  (181,
#          user_id  movie_id  rating  timestamp
#   567        231       181    0.75  888605273
#   622        245       181    0.75  888513664
#   740        276       181    1.00  874786488
#   903        150       181    1.00  878746685
#   1187        66       181    1.00  883601425
#   ...        ...       ...     ...        ...
#   98867      881       181    0.75  876535928
#   99653      889       181    0.75  880177131
#   99684      554       181    0.75  876550100
#   99745      577       181    1.00  880474612
#   99942      363       181    1.00  891494783
#
#   [361 rows x 4 columns]),
#  (100,
#          user_id  movie_id  rating  timestamp
#   50         251       100    0.75  886271884
#   621         10       100    1.00  877891747
#   1114        63       100    1.00  875747319
#   1508        65       100    0.50  879217558
#   1776        79       100    1.00  891271652
#   ...        ...       ...     ...        ...
#   99164      478       100    1.00  889388863
#   99326      376       100    0.75  879454598
#   99510      737       100    1.00  884314664
#   99608      806       100    0.75  882385063
#   99822      794       100    1.00  891035063
#
#   [353 rows x 4 columns])]

# %%
userSubsetGroup=sorted(userSubsetGroup,key=lambda x: len(x[1]), reverse=True)
userSubsetGroup[0:3]
# Out:
# <ipython-input-81-5489e10f2460>:1: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   userSubsetGroup=sorted(userSubsetGroup,key=lambda x: len(x[1]), reverse=True)
# [(405,
#          user_id  movie_id  rating  timestamp
#   12383      405       592    0.00  885548670
#   12449      405       171    0.00  885549544
#   12460      405       580    0.00  885547447
#   12607      405       387    0.00  885546680
#   12731      405       190    0.25  885546201
#   ...        ...       ...     ...        ...
#   98635      405      1475    0.00  885547268
#   98717      405       513    0.00  885546112
#   98956      405       375    0.00  885546835
#   98978      405       445    0.75  885548435
#   99756      405       958    0.00  885549590
#
#   [458 rows x 4 columns]),
#  (655,
#          user_id  movie_id  rating  timestamp
#   39347      655       274    0.50  888474872
#   39490      655       126    0.25  887426732
#   39693      655       670    0.50  887430142
#   39780      655       523    0.50  887427268
#   39786      655       736    0.50  888685734
#   ...        ...       ...     ...        ...
#   98813      655       155    0.75  887473702
#   98839      655       558    0.75  887427506
#   99071      655       143    0.75  887523176
#   99365      655       649    0.50  888685989
#   99418      655       305    0.75  887523909
#
#   [443 rows x 4 columns]),
#  (13,
#          user_id  movie_id  rating  timestamp
#   63          13       526    0.50  882141053
#   145         13       272    0.75  884538403
#   185         13        98    0.75  881515011
#   205         13       360    0.75  882140926
#   392         13       344    0.25  888073635
#   ...        ...       ...     ...        ...
#   98320       13       166    1.00  884538663
#   98615       13       822    0.50  884538634
#   99170       13       432    0.75  882398654
#   99306       13       904    0.00  892015178
#   99998       13       225    0.25  882399156
#
#   [434 rows x 4 columns])]

# %% [markdown]
# Take a suitable subset to apply the similarity measure.

# %%
pearsonCorrelationDict = {}

# For every user group in our subset
for name, group in userSubsetGroup:
    # Let's start by sorting the input and current user group so the values aren't mixed up later on
    group = group.sort_values(by='movie_id')
    inputMovies = user_input_ratings.sort_values(by='movie_id')

    # Get the N for the formula
    nRatings = len(group)

    # Get the review scores for the movies that they both have in common
    temp_df = inputMovies[inputMovies['movie_id'].isin(group['movie_id'].tolist())]

    if len(temp_df) == 0:
        print("No common movies found. Skipping this iteration.")
        continue  # Skip this iteration if there are no common movies

    # Create a merged DataFrame containing ratings for both input and current users
    merged_df = pd.merge(temp_df, group, on='movie_id', suffixes=('_input', '_group'))

    # Calculate the Pearson correlation coefficient
    correlation = merged_df['rating_input'].corr(merged_df['rating_group'])

    pearsonCorrelationDict[name] = correlation

# %% [markdown]
# Item Based

# %%
pearsonCorrelationDict = {}

# For every movie group in our subset
for name, group in movieSubsetGroup:
    # Let's start by sorting the input and current movie group so the values aren't mixed up later on
    group = group.sort_values(by='user_id')
    inputMovies = user_input_ratings.sort_values(by='user_id')

    # Get the N for the formula
    nRatings = len(group)

    # Get the review scores for the movies that they both have in common
    temp_df = inputMovies[inputMovies['user_id'].isin(group['user_id'].tolist())]

    if len(temp_df) == 0:
        print("No common users found. Skipping this iteration.")
        continue  # Skip this iteration if there are no common users

    # Create a merged DataFrame containing ratings for both input and current movies
    merged_df = pd.merge(temp_df, group, on='user_id', suffixes=('_input', '_group'))  #change

    # Calculate the Pearson correlation coefficient
    correlation = merged_df['rating_input'].corr(merged_df['rating_group'])

    pearsonCorrelationDict[name] = correlation

# %%
pearsonCorrelationDict[10]
# Out:
# 0.2637950220389173

# %%
pearsonDF = pd.DataFrame.from_dict(pearsonCorrelationDict, orient='index')
pearsonDF.columns = ['similarityIndex']
pearsonDF['userId'] = pearsonDF.index
pearsonDF.index = range(len(pearsonDF))
pearsonDF.head()
# Out:
#    similarityIndex  userId
# 0         0.081503      50
# 1         0.077328     181
# 2         0.095913     100
# 3         0.096969     288
# 4         0.053927     258

# %%
topUsers=pearsonDF.sort_values(by='similarityIndex', ascending=False)
topUsers.head(100)
# Out:
#       similarityIndex  userId
# 1355         0.843411    1259
# 1268         0.813259    1355
# 1369         0.803238    1372
# 1208         0.772630    1202
# 1305         0.762983    1295
# ...               ...     ...
# 1047         0.480346    1469
# 1319         0.477764    1422
# 1230         0.475614    1395
# 1104         0.471545    1224
# 1236         0.470400    1522
#
# [100 rows x 2 columns]

# %%
topUsersRating=topUsers.merge(ratings, left_on='userId', right_on='user_id', how='inner')
topUsersRating['weightedRating'] = topUsersRating['similarityIndex']*topUsersRating['rating']
#topUsersRating.head(18000)
topUsersRating.head(1352)
topUsersRating.isnull().sum()
# Out:
# similarityIndex    1484
# userId                0
# user_id               0
# movie_id              0
# rating                0
# weightedRating     1484
# dtype: int64

# %%
topUsersRating['similarityIndex'].fillna(0, inplace=True)
topUsersRating['weightedRating'].fillna(0, inplace=True)
topUsersRating.isnull().sum()
# Out:
# similarityIndex    0
# userId             0
# user_id            0
# movie_id           0
# rating             0
# weightedRating     0
# dtype: int64

# %%
tempTopUsersRating = topUsersRating.groupby('movie_id').sum()[['similarityIndex','weightedRating']]
tempTopUsersRating.columns = ['sum_similarityIndex','sum_weightedRating']
recommendation_df = pd.DataFrame()
recommendation_df['weighted average recommendation score'] = tempTopUsersRating['sum_weightedRating']/tempTopUsersRating['sum_similarityIndex']
#handled the zero division error bug
recommendation_df.loc[tempTopUsersRating['sum_similarityIndex'] == 0, 'weighted average recommendation score'] = 0
recommendation_df.fillna(0, inplace=True)
##
recommendation_df['movieID'] = tempTopUsersRating.index
recommendation_df.tail()
# Out:
#           weighted average recommendation score  movieID
# movie_id
# 1678                                      -0.00     1678
# 1679                                       0.50     1679
# 1680                                       0.25     1680
# 1681                                       0.50     1681
# 1682                                       0.50     1682

# %%
tempTopUsersRating.head(973)
# Out:
#           sum_similarityIndex  sum_weightedRating
# movie_id
# 1                   75.481818           53.428368
# 2                   21.681213           12.191728
# 3                   15.303852            7.700109
# 4                   36.288654           22.614475
# 5                   15.272884            9.271987
# ...                       ...                 ...
# 969                 13.362993            9.089493
# 970                  1.814274            0.987795
# 971                  6.921599            4.562351
# 972                  4.726428            2.518854
# 973                  1.094491            0.490654
#
# [973 rows x 2 columns]

# %%
recommendation_df = recommendation_df.sort_values(by='weighted average recommendation score', ascending=False)
recommendation_df.head(100)
# Out:
#           weighted average recommendation score  movieID
# movie_id
# 1607                                   2.060375     1607
# 1189                                   1.000000     1189
# 1293                                   1.000000     1293
# 1122                                   1.000000     1122
# 814                                    1.000000      814
# ...                                         ...      ...
# 524                                    0.777063      524
# 59                                     0.775973       59
# 89                                     0.775685       89
# 45                                     0.773682       45
# 189                                    0.773595      189
#
# [100 rows x 2 columns]

# %%
recommendation_df = recommendation_df[(recommendation_df['weighted average recommendation score'] <= 5) &
 (recommendation_df['weighted average recommendation score'] >= 0) &
 (recommendation_df['weighted average recommendation score'].notnull())]
print(recommendation_df)
# Out:
#           weighted average recommendation score  movieID
# movie_id
# 1607                                   2.060375     1607
# 1189                                   1.000000     1189
# 1293                                   1.000000     1293
# 1122                                   1.000000     1122
# 814                                    1.000000      814
# ...                                         ...      ...
# 1565                                   0.000000     1565
# 1566                                   0.000000     1566
# 1567                                   0.000000     1567
# 1568                                   0.000000     1568
# 1320                                   0.000000     1320
#
# [1673 rows x 2 columns]

# %%
print(recommendation_df.isnull().sum())
# Out:
# weighted average recommendation score    0
# movieID                                  0
# dtype: int64

# %%
recommendation_df.head(10)
# Out:
#           weighted average recommendation score  movieID
# movie_id
# 1607                                   2.060375     1607
# 1189                                   1.000000     1189
# 1293                                   1.000000     1293
# 1122                                   1.000000     1122
# 814                                    1.000000      814
# 1536                                   1.000000     1536
# 1467                                   1.000000     1467
# 1653                                   1.000000     1653
# 1500                                   1.000000     1500
# 1191                                   1.000000     1191

# %%
movies.loc[movies['movie_id'].isin(recommendation_df.head(10)['movieID'].tolist())]
# Out:
#       movie_id                                              title release_date
# 813        814                      Great Day in Harlem, A (1994)  01-Jan-1994
# 1121      1122                     They Made Me a Criminal (1939)  01-Jan-1939
# 1188      1189                                 Prefontaine (1997)  24-Jan-1997
# 1190      1191                    Letter From Death Row, A (1998)  01-Feb-1998
# 1292      1293                                    Star Kid (1997)  16-Jan-1998
# 1466      1467               Saint of Fort Washington, The (1993)  01-Jan-1993
# 1499      1500                          Santa with Muscles (1996)  08-Nov-1996
# 1535      1536                               Aiqing wansui (1994)  22-Jul-1996
# 1606      1607                           Hurricane Streets (1998)  01-Jan-1998
# 1652      1653  Entertaining Angels: The Dorothy Day Story (1996)  27-Sep-1996

# %%
from math import sqrt
merged_ratings = pd.merge(recommendation_df, ratings,on='movie_id')
merged_ratings['squared_diff'] = (merged_ratings['weighted average recommendation score'] - merged_ratings['rating']) ** 2
mean_squared_diff = merged_ratings['squared_diff'].mean()
mean_squared_diff
rmse_score = sqrt(mean_squared_diff)
print("RMSE Score:", rmse_score)
# Out:
# RMSE Score: 0.25132853605906713

# %%
import pandas as pd
from math import sqrt
merged_ratings = pd.merge(recommendation_df, ratings, on='movie_id')

merged_ratings['abs_diff'] = abs(merged_ratings['weighted average recommendation score'] - merged_ratings['rating'])

mae_score = merged_ratings['abs_diff'].mean()

print("MAE Score:", mae_score)
# Out:
# MAE Score: 0.2005340636421621

# %%
userItemMatrix = ratings_df.pivot_table(index='user_id', columns='movie_id', values='rating')
userItemMatrix

#dont proceed from here
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-98-29bd8e09d5d6> in <cell line: 1>()
# ----> 1 userItemMatrix = ratings_df.pivot_table(index='user_id', columns='movie_id', values='rating')
#       2 userItemMatrix
#       3
#       4 #dont proceed from here
#
# NameError: name 'ratings_df' is not defined

# %%
numNaN = userItemMatrix.isnull().sum().sum()
numNaN

# %%
topMovieIDs = recommendation_df['movieID'].head(20)
topMovieRatings = ratings[ratings['movie_id'].isin(topMovieIDs)]
avgRating = topMovieRatings['rating'].mean()
avgRating

# %%
numNaN = userItemMatrix.isnull().sum().sum()
numNaN

# %%
import numpy as np
import pandas as pd

num_items = userItemMatrix.shape[1]

non_empty_counts = userItemMatrix.notna().sum(axis=1)

empty_percentage = (1 - non_empty_counts / num_items) * 100

threshold = 60

userItemMatrix.loc[empty_percentage > threshold] = userItemMatrix.loc[empty_percentage > threshold].fillna(avgRating)

# %%
numNaN = userItemMatrix.isnull().sum().sum()
numNaN

# %%
userItemMatrix

# %%
ratings_series = userItemMatrix.stack()
ratings_df = ratings_series.reset_index()
ratings_df.columns = ['user_id', 'movie_id', 'rating']

# %%
print(len(ratings))

# %%
print(len(ratings_df))

# %%
user_input_percent = 0.3
subset_percent = 0.7

num_ratings = len(ratings_df)
num_user_input = int(num_ratings * user_input_percent)
num_subset = int(num_ratings * subset_percent)

user_input_ratings = ratings.sample(n=num_user_input, replace=True, random_state=42)
subset_ratings = ratings.drop(user_input_ratings.index)
user_input_ratings

# %%
userSubset = subset_ratings[subset_ratings['movie_id'].isin(user_input_ratings['movie_id'].tolist())]
userSubset.head()

# %%
userSubsetGroup = userSubset.groupby(['user_id'])
userSubsetGroup.get_group(222)

# %%
movieSubsetGroup = userSubset.groupby(['movie_id'])
movieSubsetGroup.get_group(222)

# %%
movieSubsetGroup=sorted(movieSubsetGroup,key=lambda x: len(x[1]), reverse=True)
movieSubsetGroup[0:3]

# %%
userSubsetGroup=sorted(userSubsetGroup,key=lambda x: len(x[1]), reverse=True)
userSubsetGroup[0:3]

# %%
genres = pd.read_csv('/content/drive/MyDrive/ml-100k/u.item', sep="|", encoding='latin-1', header=None)
genres.columns = ['movie id', 'movie title' ,'release date','video release date', 'IMDb URL', 'unknown', 'Action',
                'Adventure', 'Animation', 'Children\'s', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Fantasy', 'Film-Noir',
                'Horror', 'Musical', 'Mystery', 'Romance', 'Sci-Fi', 'Thriller', 'War', 'Western']
genres.head()

# %%
genres.drop(["release date", "video release date", "IMDb URL"], inplace=True, axis=1)

# %%
genres.tail()

# %%
genre_columns= [ 'unknown', 'Action',
                'Adventure', 'Animation', 'Children\'s', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Fantasy', 'Film-Noir',
                'Horror', 'Musical', 'Mystery', 'Romance', 'Sci-Fi', 'Thriller', 'War', 'Western']
genres['genres'] = genres.apply(lambda x: [genre for genre in genre_columns if x[genre] == 1], axis=1)

# %%
genres.head()

# %%
genres = genres.drop(columns=genre_columns)

# %%
genres.head()
